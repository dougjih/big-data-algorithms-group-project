# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd

# %%
# %%time
def read_vaers_data(filename):
    return pd.read_csv(filename, index_col='VAERS_ID', encoding='iso-8859-1', low_memory=False, memory_map=True)

data = read_vaers_data('./data/2021VAERSDATA.csv')
symptoms = read_vaers_data('./data/2021VAERSSYMPTOMS.csv')
vax = read_vaers_data('./data/2021VAERSVAX.csv')
# Out:
# CPU times: user 6.19 s, sys: 3.34 s, total: 9.53 s
# Wall time: 20.5 s

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 654986 entries, 916600 to 1828454
# Data columns (total 34 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   RECVDATE      654986 non-null  object
#  1   STATE         572236 non-null  object
#  2   AGE_YRS       583424 non-null  float64
#  3   CAGE_YR       518587 non-null  float64
#  4   CAGE_MO       3182 non-null    float64
#  5   SEX           654986 non-null  object
#  6   RPT_DATE      350 non-null     object
#  7   SYMPTOM_TEXT  654828 non-null  object
#  8   DIED          8536 non-null    object
#  9   DATEDIED      7550 non-null    object
#  10  L_THREAT      9957 non-null    object
#  11  ER_VISIT      52 non-null      object
#  12  HOSPITAL      39734 non-null   object
#  13  HOSPDAYS      26819 non-null   float64
#  14  X_STAY        339 non-null     object
#  15  DISABLE       10371 non-null   object
#  16  RECOVD        595432 non-null  object
#  17  VAX_DATE      606079 non-null  object
#  18  ONSET_DATE    598509 non-null  object
#  19  NUMDAYS       572835 non-null  float64
#  20  LAB_DATA      253022 non-null  object
#  21  V_ADMINBY     654986 non-null  object
#  22  V_FUNDBY      393 non-null     object
#  23  OTHER_MEDS    376699 non-null  object
#  24  CUR_ILL       296466 non-null  object
#  25  HISTORY       402178 non-null  object
#  26  PRIOR_VAX     30739 non-null   object
#  27  SPLTTYPE      198600 non-null  object
#  28  FORM_VERS     654986 non-null  int64
#  29  TODAYS_DATE   651215 non-null  object
#  30  BIRTH_DEFECT  383 non-null     object
#  31  OFC_VISIT     124763 non-null  object
#  32  ER_ED_VISIT   79719 non-null   object
#  33  ALLERGIES     330630 non-null  object
# dtypes: float64(5), int64(1), object(28)
# memory usage: 174.9+ MB

# %%
symptoms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 875131 entries, 916600 to 1828454
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SYMPTOM1         875131 non-null  object
#  1   SYMPTOMVERSION1  875131 non-null  float64
#  2   SYMPTOM2         683341 non-null  object
#  3   SYMPTOMVERSION2  683341 non-null  float64
#  4   SYMPTOM3         526263 non-null  object
#  5   SYMPTOMVERSION3  526263 non-null  float64
#  6   SYMPTOM4         399438 non-null  object
#  7   SYMPTOMVERSION4  399438 non-null  float64
#  8   SYMPTOM5         297604 non-null  object
#  9   SYMPTOMVERSION5  297604 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 73.4+ MB

# %%
vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 689290 entries, 916600 to 1828454
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAX_TYPE         689290 non-null  object
#  1   VAX_MANU         689290 non-null  object
#  2   VAX_LOT          472898 non-null  object
#  3   VAX_DOSE_SERIES  685885 non-null  object
#  4   VAX_ROUTE        519639 non-null  object
#  5   VAX_SITE         501263 non-null  object
#  6   VAX_NAME         689290 non-null  object
# dtypes: object(7)
# memory usage: 42.1+ MB

# %%
vax['VAX_TYPE'].unique()
# Out:
# array(['COVID19', 'FLUC4', 'DTAPHEPBIP', 'HIBV', 'PNC13', 'RV1', 'UNK',
#        'FLU4', 'PPV', 'FLUA3', 'VARZOS', 'MMR', 'DT', 'HPV9', 'DTAP',
#        'MMRV', 'TDAP', 'FLUR4', 'DTAPIPVHIB', 'HEPA', 'MNQ', 'FLUX', 'YF',
#        'ANTH', 'HEP', 'VARCEL', 'RV5', 'HPV4', 'MENB', 'IPV', 'RAB',
#        'FLUA4', 'FLUN4', 'DTAPIPV', 'TYP', 'ADEN_4_7', 'CHOL', 'TTOX',
#        'FLU3', 'FLUC3', 'HEPAB', 'TD', 'EBZR', 'PNC', 'DF', 'HPVX',
#        'FLUX(H1N1)', 'RVX', 'DTP', 'MEN', 'JEV1', 'BCG', 'PER', 'SMALL',
#        'OPV', 'TDAPIPV', 'MENHIB', 'FLUN3', 'FLU(H1N1)', 'MNQHIB',
#        'DTPHEP', 'JEVX', 'DTPPVHBHPB', '6VAX-F'], dtype=object)

# %%
joined = data.join(symptoms).join(vax)

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 926331 entries, 916600 to 1828454
# Data columns (total 51 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   RECVDATE         926331 non-null  object
#  1   STATE            823668 non-null  object
#  2   AGE_YRS          842540 non-null  float64
#  3   CAGE_YR          751376 non-null  float64
#  4   CAGE_MO          6242 non-null    float64
#  5   SEX              926331 non-null  object
#  6   RPT_DATE         490 non-null     object
#  7   SYMPTOM_TEXT     926157 non-null  object
#  8   DIED             15966 non-null   object
#  9   DATEDIED         14689 non-null   object
#  10  L_THREAT         23183 non-null   object
#  11  ER_VISIT         79 non-null      object
#  12  HOSPITAL         91230 non-null   object
#  13  HOSPDAYS         66093 non-null   float64
#  14  X_STAY           700 non-null     object
#  15  DISABLE          23286 non-null   object
#  16  RECOVD           851855 non-null  object
#  17  VAX_DATE         867383 non-null  object
#  18  ONSET_DATE       859984 non-null  object
#  19  NUMDAYS          823269 non-null  float64
#  20  LAB_DATA         428274 non-null  object
#  21  V_ADMINBY        926331 non-null  object
#  22  V_FUNDBY         544 non-null     object
#  23  OTHER_MEDS       578098 non-null  object
#  24  CUR_ILL          457110 non-null  object
#  25  HISTORY          610929 non-null  object
#  26  PRIOR_VAX        49059 non-null   object
#  27  SPLTTYPE         262920 non-null  object
#  28  FORM_VERS        926331 non-null  int64
#  29  TODAYS_DATE      919896 non-null  object
#  30  BIRTH_DEFECT     712 non-null     object
#  31  OFC_VISIT        209745 non-null  object
#  32  ER_ED_VISIT      151345 non-null  object
#  33  ALLERGIES        508929 non-null  object
#  34  SYMPTOM1         926328 non-null  object
#  35  SYMPTOMVERSION1  926328 non-null  float64
#  36  SYMPTOM2         725250 non-null  object
#  37  SYMPTOMVERSION2  725250 non-null  float64
#  38  SYMPTOM3         558713 non-null  object
#  39  SYMPTOMVERSION3  558713 non-null  float64
#  40  SYMPTOM4         425493 non-null  object
#  41  SYMPTOMVERSION4  425493 non-null  float64
#  42  SYMPTOM5         318564 non-null  object
#  43  SYMPTOMVERSION5  318564 non-null  float64
#  44  VAX_TYPE         926331 non-null  object
#  45  VAX_MANU         926331 non-null  object
#  46  VAX_LOT          647382 non-null  object
#  47  VAX_DOSE_SERIES  921405 non-null  object
#  48  VAX_ROUTE        708683 non-null  object
#  49  VAX_SITE         692130 non-null  object
#  50  VAX_NAME         926331 non-null  object
# dtypes: float64(10), int64(1), object(40)
# memory usage: 367.5+ MB

# %%
joined.head()
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916600    01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 916601    01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 916602    01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 916603    01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 916604    01/01/2021    TX     47.0     47.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED DATEDIED  \
# VAERS_ID
# 916600    Right side of epiglottis swelled up and hinder...  NaN      NaN
# 916601    Approximately 30 min post vaccination administ...  NaN      NaN
# 916602    About 15 minutes after receiving the vaccine, ...  NaN      NaN
# 916603    extreme fatigue, dizziness,. could not lift my...  NaN      NaN
# 916604    Injection site swelling, redness, warm to the ...  NaN      NaN
#
#           ... SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5  VAX_TYPE  \
# VAERS_ID  ...
# 916600    ...             NaN      NaN             NaN   COVID19
# 916601    ...             NaN      NaN             NaN   COVID19
# 916602    ...            23.1      NaN             NaN   COVID19
# 916603    ...             NaN      NaN             NaN   COVID19
# 916604    ...            23.1      NaN             NaN   COVID19
#
#                  VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# VAERS_ID
# 916600            MODERNA  037K20A               1        IM       LA
# 916601            MODERNA  025L20A               1        IM       RA
# 916602    PFIZER\BIONTECH   EL1284               1        IM       LA
# 916603            MODERNA  unknown             UNK       NaN      NaN
# 916604            MODERNA      NaN               1        IM       LA
#
#                                      VAX_NAME
# VAERS_ID
# 916600            COVID19 (COVID19 (MODERNA))
# 916601            COVID19 (COVID19 (MODERNA))
# 916602    COVID19 (COVID19 (PFIZER-BIONTECH))
# 916603            COVID19 (COVID19 (MODERNA))
# 916604            COVID19 (COVID19 (MODERNA))
#
# [5 rows x 51 columns]

# %%
joined.loc[916611]
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916611    01/01/2021    NC     33.0     33.0      NaN   F      NaN
# 916611    01/01/2021    NC     33.0     33.0      NaN   F      NaN
# 916611    01/01/2021    NC     33.0     33.0      NaN   F      NaN
# 916611    01/01/2021    NC     33.0     33.0      NaN   F      NaN
# 916611    01/01/2021    NC     33.0     33.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED DATEDIED  \
# VAERS_ID
# 916611    12pm Received shot 1 pm Sore arm at injection ...  NaN      NaN
# 916611    12pm Received shot 1 pm Sore arm at injection ...  NaN      NaN
# 916611    12pm Received shot 1 pm Sore arm at injection ...  NaN      NaN
# 916611    12pm Received shot 1 pm Sore arm at injection ...  NaN      NaN
# 916611    12pm Received shot 1 pm Sore arm at injection ...  NaN      NaN
#
#           ... SYMPTOMVERSION4                    SYMPTOM5 SYMPTOMVERSION5  \
# VAERS_ID  ...
# 916611    ...            23.1          Decreased appetite            23.1
# 916611    ...            23.1                    Headache            23.1
# 916611    ...            23.1  Musculoskeletal chest pain            23.1
# 916611    ...            23.1                     Pyrexia            23.1
# 916611    ...             NaN                         NaN             NaN
#
#           VAX_TYPE VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# VAERS_ID
# 916611     COVID19  MODERNA  039k20a               1       SYR       RA
# 916611     COVID19  MODERNA  039k20a               1       SYR       RA
# 916611     COVID19  MODERNA  039k20a               1       SYR       RA
# 916611     COVID19  MODERNA  039k20a               1       SYR       RA
# 916611     COVID19  MODERNA  039k20a               1       SYR       RA
#
#                              VAX_NAME
# VAERS_ID
# 916611    COVID19 (COVID19 (MODERNA))
# 916611    COVID19 (COVID19 (MODERNA))
# 916611    COVID19 (COVID19 (MODERNA))
# 916611    COVID19 (COVID19 (MODERNA))
# 916611    COVID19 (COVID19 (MODERNA))
#
# [5 rows x 51 columns]

# %%
joined[joined['DIED'] == 'Y']
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916803    01/01/2021    LA     78.0     78.0      NaN   M      NaN
# 917117    01/01/2021    AR     82.0     82.0      NaN   M      NaN
# 917790    01/03/2021    AR     90.0     90.0      NaN   F      NaN
# 917793    01/03/2021    AR     78.0     78.0      NaN   F      NaN
# 918065    01/04/2021    CA     64.0     64.0      NaN   M      NaN
# ...              ...   ...      ...      ...      ...  ..      ...
# 1828059   10/29/2021   NaN      NaN      NaN      NaN   M      NaN
# 1828410   10/29/2021    PA      NaN      NaN      NaN   F      NaN
# 1828442   10/29/2021   NaN     98.0     98.0      NaN   F      NaN
# 1828442   10/29/2021   NaN     98.0     98.0      NaN   F      NaN
# 1828445   10/29/2021    OH     84.0     84.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED    DATEDIED  \
# VAERS_ID
# 916803                                     respitory colase    Y  10/18/2020
# 917117    After vaccination, patient tested positive for...    Y  01/01/2021
# 917790    At the time of vaccination, there was an outbr...    Y  01/03/2021
# 917793    Prior to the administration of the COVID 19 va...    Y  01/02/2021
# 918065    1/1/2020: Residents was found unresponsive. Pr...    Y  01/01/2021
# ...                                                     ...  ...         ...
# 1828059   cancer; Initial information was received on 22...    Y         NaN
# 1828410   Nobody was listening to her.She couldn't take ...    Y         NaN
# 1828442   After receiving both doses of Moderna COVID va...    Y  09/06/2021
# 1828442   After receiving both doses of Moderna COVID va...    Y  09/06/2021
# 1828445                 observed resident to be passed away    Y  10/28/2021
#
#           ... SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5  VAX_TYPE  \
# VAERS_ID  ...
# 916803    ...             NaN      NaN             NaN      FLU4
# 917117    ...             NaN      NaN             NaN   COVID19
# 917790    ...            23.1      NaN             NaN   COVID19
# 917793    ...             NaN      NaN             NaN   COVID19
# 918065    ...             NaN      NaN             NaN   COVID19
# ...       ...             ...      ...             ...       ...
# 1828059   ...             NaN      NaN             NaN      FLUX
# 1828410   ...             NaN      NaN             NaN   COVID19
# 1828442   ...            24.1      NaN             NaN   COVID19
# 1828442   ...            24.1      NaN             NaN   COVID19
# 1828445   ...             NaN      NaN             NaN   COVID19
#
#                       VAX_MANU    VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# VAERS_ID
# 916803          SANOFI PASTEUR        NaN               4        IM      NaN
# 917117                 MODERNA        NaN               1        IM       AR
# 917790                 MODERNA        NaN               1        IM       AR
# 917793                 MODERNA        NaN               1        IM       AR
# 918065                 MODERNA  025J20-2A               1        IM      NaN
# ...                        ...        ...             ...       ...      ...
# 1828059   UNKNOWN MANUFACTURER        NaN             UNK        OT      NaN
# 1828410                MODERNA        NaN             UNK        OT      NaN
# 1828442                MODERNA    012L20A               1        IM       AR
# 1828442                MODERNA    031L20A               2        IM       AR
# 1828445        PFIZER\BIONTECH    320308D             UNK        IM       LA
#
#                                                    VAX_NAME
# VAERS_ID
# 916803    INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE QUADRI...
# 917117                          COVID19 (COVID19 (MODERNA))
# 917790                          COVID19 (COVID19 (MODERNA))
# 917793                          COVID19 (COVID19 (MODERNA))
# 918065                          COVID19 (COVID19 (MODERNA))
# ...                                                     ...
# 1828059                INFLUENZA (SEASONAL) (NO BRAND NAME)
# 1828410                         COVID19 (COVID19 (MODERNA))
# 1828442                         COVID19 (COVID19 (MODERNA))
# 1828442                         COVID19 (COVID19 (MODERNA))
# 1828445                 COVID19 (COVID19 (PFIZER-BIONTECH))
#
# [15966 rows x 51 columns]
